# %%
from Functions import*

# %%
import glob

# %%
#function that create a list from lines in a txt file
#allows to know which image is in which set
def create_list_from_txt(filename):
    FILE = filename
 
    with open(FILE, 'r') as f:
        lines = [line.strip('\n') for line in f.readlines()]
 
    list_img = [line for line in lines]
    
    return list_img

# %%
#function that create the lists of image but already split in test, train and val sets
#we are going to use this function to load data in the right sets
#two times  for COVID and NonCOVID

#set_type is either train,test or val
def create_set_list_splits(covid): 
    folder_path='/tf/Project/Data_split'
    if covid==True:
        set_dir=os.path.join(folder_path+'/COVID')
    else: 
        set_dir=os.path.join(folder_path+'/NonCOVID')
    
    
    list_files=glob.glob(set_dir+'/*.txt')
    list_files.sort()
    #to ensure the order of sets as test , train and val (alphabetic order)
    
    
    test_list=create_list_from_txt(list_files[0])
    train_list=create_list_from_txt(list_files[1])
    val_list=create_list_from_txt(list_files[2])
    
    return test_list, train_list, val_list

# %%
#add the name of image to the name of folder
#create the full name of the image to be loaded
def list_dir(set_list,set_dir):
    new_data=[]
    for x in set_list:
        new = os.path.join(set_dir,x)
        new_data.append(new)
    return new_data

# %%
#tbl stands for to be loaded
def create_list_to_load(test_list,train_list, val_list, covid):
    img_path='/tf/Project'
    
    if covid==True:
        set_dir=os.path.join(img_path+'/CT_COVID')
    else: 
        set_dir=os.path.join(img_path+'/CT_NonCOVID')
    
    test_list_tbl=list_dir(test_list,set_dir)
    train_list_tbl=list_dir(train_list,set_dir)
    val_list_tbl=list_dir(val_list,set_dir)
    
    return test_list_tbl, train_list_tbl, val_list_tbl

# %%
def load_data(data_list,img_w,img_h,img_ch):
    tab = np.zeros((len(data_list),img_w,img_h,img_ch),dtype='float32')
    for i in range(len(data_list)):
        Img = cv2.imread(data_list[i],0)
        Img = cv2.resize(Img,(img_w, img_h))
        Img = Img.reshape(img_w,img_h)/255
        tab[i,:,:,0]=Img
    return tab

# %%
def create_list_labels(set_list,covid): 
    list_labels=[]
    for i in range(len(set_list)):
        if covid==True:
            list_labels.append(1)
        else:
            list_labels.append(0)
    return list_labels

# %%
def concatenate_lists_and_labels(list1,labels1,list2,labels2):
    return list1+list2, labels1+labels2

# %%
def shuffle_lists(list_img, list_labels):
    index_position = list(zip(list_img, list_labels))
    random.shuffle(index_position)
    list_img[:],list_labels[:] = zip(*index_position)
    return list_img,list_labels

# %%
def precision(y_true,y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + K.epsilon()) / (K.sum(y_pred_f) + K.epsilon())

def recall(y_true,y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + K.epsilon()) / (K.sum(y_true_f) + K.epsilon())

# %%
#labels is an array
def augmentation(image_set,labels,dictionary_augmentation,batch_size):
    
    image_datagen = ImageDataGenerator(**dictionary_augmentation)

    image_generator = image_datagen.flow(
    image_set,
    y=labels,
    batch_size=batch_size,
    shuffle=False,
    seed=1)

    
    
    return image_generator

# %%
test_list_covid, train_list_covid, val_list_covid=create_set_list_splits(covid=True)
test_list_Noncovid, train_list_Noncovid, val_list_Noncovid=create_set_list_splits(covid=False)

# %%
test_list_tbl_covid, train_list_tbl_covid,val_list_tbl_covid=create_list_to_load(test_list_covid,train_list_covid, val_list_covid, covid=True)

test_list_tbl_Noncovid, train_list_tbl_Noncovid,val_list_tbl_Noncovid=create_list_to_load(test_list_Noncovid,train_list_Noncovid, val_list_Noncovid, covid=False)

# %%
test_covid_labels=create_list_labels(test_list_covid,covid=True)
train_covid_labels=create_list_labels(train_list_covid,covid=True)
val_covid_labels=create_list_labels(val_list_covid,covid=True)

test_Noncovid_labels=create_list_labels(test_list_Noncovid,covid=False)
train_Noncovid_labels=create_list_labels(train_list_Noncovid,covid=False)
val_Noncovid_labels=create_list_labels(val_list_Noncovid,covid=False)

# %%
test_list_tbl,test_labels=concatenate_lists_and_labels(test_list_tbl_covid,test_covid_labels,test_list_tbl_Noncovid,test_Noncovid_labels)
train_list_tbl,train_labels=concatenate_lists_and_labels(train_list_tbl_covid,train_covid_labels,train_list_tbl_Noncovid,train_Noncovid_labels)
val_list_tbl,val_labels=concatenate_lists_and_labels(val_list_tbl_covid,val_covid_labels,val_list_tbl_Noncovid,val_Noncovid_labels)

# %%
test_list_tbl,test_labels=shuffle_lists(test_list_tbl, test_labels)
train_list_tbl,train_labels=shuffle_lists(train_list_tbl, train_labels)
val_list_tbl,val_labels=shuffle_lists(val_list_tbl, val_labels)

# %%
#the article precises the size of the images as (480,480)

img_w,img_h,img_ch=480,480,1

test_set=load_data(test_list_tbl,img_w,img_h,img_ch)
train_set=load_data(train_list_tbl,img_w,img_h,img_ch)
val_set=load_data(val_list_tbl,img_w,img_h,img_ch)

test_labels=np.array(test_labels)
train_labels=np.array(train_labels)
val_labels=np.array(val_labels)

# %%
from skimage.io import imshow

# %%
imshow(np.squeeze(test_set[0]))

# %%
from tensorflow.keras.layers import Conv2D,AveragePooling2D,add, GlobalAveragePooling2D, ReLU

# %%
INPUT_SHAPE=480,480,1
N_CLASSES=1

K.clear_session()
my_model=densenet(INPUT_SHAPE,N_CLASSES,dropout=True,dr=0.2)
my_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 480, 480, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 240, 240, 64) 3200        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 120, 120, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_1 (Batch (None, 120, 120, 64) 256         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 120, 120, 64) 0           batch_normalization_v2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 120, 120, 32) 18464       re_lu_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 120, 120, 96) 0           conv2d_2[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_3 (Batch (None, 120, 120, 96) 384         concatenate[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 120, 120, 96) 0           batch_normalization_v2_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 120, 120, 32) 27680       re_lu_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 120, 120, 128 0           conv2d_4[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_5 (Batch (None, 120, 120, 128 512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 120, 120, 128 0           batch_normalization_v2_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 120, 120, 32) 36896       re_lu_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 120, 120, 160 0           conv2d_6[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_7 (Batch (None, 120, 120, 160 640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 120, 120, 160 0           batch_normalization_v2_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 120, 120, 32) 46112       re_lu_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 120, 120, 192 0           conv2d_8[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_9 (Batch (None, 120, 120, 192 768         concatenate_3[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 120, 120, 192 0           batch_normalization_v2_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 120, 120, 32) 55328       re_lu_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 120, 120, 224 0           conv2d_10[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_11 (Batc (None, 120, 120, 224 896         concatenate_4[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 120, 120, 224 0           batch_normalization_v2_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 120, 120, 32) 64544       re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 120, 120, 256 0           conv2d_12[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_12 (Batc (None, 120, 120, 256 1024        concatenate_5[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 120, 120, 256 0           batch_normalization_v2_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 120, 120, 128 32896       re_lu_12[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 120, 120, 128 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 60, 60, 128)  0           dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_14 (Batc (None, 60, 60, 128)  512         average_pooling2d[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 60, 60, 128)  0           batch_normalization_v2_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 60, 60, 32)   36896       re_lu_14[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 60, 60, 160)  0           conv2d_15[0][0]
#                                                                  average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_16 (Batc (None, 60, 60, 160)  640         concatenate_6[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 60, 60, 160)  0           batch_normalization_v2_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 60, 60, 32)   46112       re_lu_16[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 60, 60, 192)  0           conv2d_17[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_18 (Batc (None, 60, 60, 192)  768         concatenate_7[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 60, 60, 192)  0           batch_normalization_v2_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 60, 60, 32)   55328       re_lu_18[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 60, 60, 224)  0           conv2d_19[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_20 (Batc (None, 60, 60, 224)  896         concatenate_8[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 60, 60, 224)  0           batch_normalization_v2_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 60, 60, 32)   64544       re_lu_20[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 60, 60, 256)  0           conv2d_21[0][0]
#                                                                  concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_22 (Batc (None, 60, 60, 256)  1024        concatenate_9[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 60, 60, 256)  0           batch_normalization_v2_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 60, 60, 32)   73760       re_lu_22[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 60, 60, 288)  0           conv2d_23[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_24 (Batc (None, 60, 60, 288)  1152        concatenate_10[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 60, 60, 288)  0           batch_normalization_v2_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 60, 60, 32)   82976       re_lu_24[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 60, 60, 320)  0           conv2d_25[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_25 (Batc (None, 60, 60, 320)  1280        concatenate_11[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 60, 60, 320)  0           batch_normalization_v2_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 60, 60, 160)  51360       re_lu_25[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 60, 60, 160)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 30, 30, 160)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_27 (Batc (None, 30, 30, 160)  640         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 30, 30, 160)  0           batch_normalization_v2_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 30, 30, 32)   46112       re_lu_27[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 30, 30, 192)  0           conv2d_28[0][0]
#                                                                  average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_29 (Batc (None, 30, 30, 192)  768         concatenate_12[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 30, 30, 192)  0           batch_normalization_v2_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 30, 30, 32)   55328       re_lu_29[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 30, 30, 224)  0           conv2d_30[0][0]
#                                                                  concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_31 (Batc (None, 30, 30, 224)  896         concatenate_13[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 30, 30, 224)  0           batch_normalization_v2_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 30, 30, 32)   64544       re_lu_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 30, 30, 256)  0           conv2d_32[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_33 (Batc (None, 30, 30, 256)  1024        concatenate_14[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 30, 30, 256)  0           batch_normalization_v2_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 30, 30, 32)   73760       re_lu_33[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 30, 30, 288)  0           conv2d_34[0][0]
#                                                                  concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_35 (Batc (None, 30, 30, 288)  1152        concatenate_15[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 30, 30, 288)  0           batch_normalization_v2_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 30, 30, 32)   82976       re_lu_35[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 30, 30, 320)  0           conv2d_36[0][0]
#                                                                  concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_37 (Batc (None, 30, 30, 320)  1280        concatenate_16[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 30, 30, 320)  0           batch_normalization_v2_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 30, 30, 32)   92192       re_lu_37[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 30, 30, 352)  0           conv2d_38[0][0]
#                                                                  concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_38 (Batc (None, 30, 30, 352)  1408        concatenate_17[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 30, 30, 352)  0           batch_normalization_v2_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 30, 30, 176)  62128       re_lu_38[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 30, 30, 176)  0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 15, 15, 176)  0           dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_40 (Batc (None, 15, 15, 176)  704         average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 15, 15, 176)  0           batch_normalization_v2_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 15, 15, 32)   50720       re_lu_40[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 15, 15, 208)  0           conv2d_41[0][0]
#                                                                  average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_42 (Batc (None, 15, 15, 208)  832         concatenate_18[0][0]
# __________________________________________________________________________________________________
# re_lu_42 (ReLU)                 (None, 15, 15, 208)  0           batch_normalization_v2_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 15, 15, 32)   59936       re_lu_42[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 15, 15, 240)  0           conv2d_43[0][0]
#                                                                  concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_44 (Batc (None, 15, 15, 240)  960         concatenate_19[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, 15, 15, 240)  0           batch_normalization_v2_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 15, 15, 32)   69152       re_lu_44[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 15, 15, 272)  0           conv2d_45[0][0]
#                                                                  concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_46 (Batc (None, 15, 15, 272)  1088        concatenate_20[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, 15, 15, 272)  0           batch_normalization_v2_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 15, 15, 32)   78368       re_lu_46[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 15, 15, 304)  0           conv2d_47[0][0]
#                                                                  concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_48 (Batc (None, 15, 15, 304)  1216        concatenate_21[0][0]
# __________________________________________________________________________________________________
# re_lu_48 (ReLU)                 (None, 15, 15, 304)  0           batch_normalization_v2_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 15, 15, 32)   87584       re_lu_48[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 15, 15, 336)  0           conv2d_49[0][0]
#                                                                  concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v2_50 (Batc (None, 15, 15, 336)  1344        concatenate_22[0][0]
# __________________________________________________________________________________________________
# re_lu_50 (ReLU)                 (None, 15, 15, 336)  0           batch_normalization_v2_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 15, 15, 32)   96800       re_lu_50[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 15, 15, 368)  0           conv2d_51[0][0]
#                                                                  concatenate_22[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 368)          0           concatenate_23[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            369         global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 1,640,129
# Trainable params: 1,628,097
# Non-trainable params: 12,032
# __________________________________________________________________________________________________

# %%
learning_rate=0.00001
optimizer=Adam(learning_rate)
batch_size=16
loss_function = 'binary_crossentropy'
metrics=['binary_accuracy',precision,recall]
n_epochs=100

# %%
#data augmentation
dictionary_augmentation = dict(
                     rotation_range=10,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     zoom_range=0.2,       
                     horizontal_flip=True,
                     brightness_range=[0,2])

# %%
 STEP_SIZE_TRAIN=len(train_set)//batch_size

# %%
train_generator=augmentation(train_set,train_labels,dictionary_augmentation,batch_size)

# %%
my_model.compile(loss=loss_function,optimizer = optimizer,metrics=['binary_accuracy'])

# %%
model_hist=my_model.fit_generator(generator=train_generator,
                        steps_per_epoch=STEP_SIZE_TRAIN,
                        validation_data=(val_set,val_labels)
                        ,epochs=n_epochs,verbose=1)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 22s 845ms/step - loss: 0.6912 - binary_accuracy: 0.5452 - val_loss: 0.6930 - val_binary_accuracy: 0.5085
# Epoch 2/100
# 26/26 [==============================] - 6s 239ms/step - loss: 0.6812 - binary_accuracy: 0.5575 - val_loss: 0.6938 - val_binary_accuracy: 0.4915
# Epoch 3/100
# 26/26 [==============================] - 6s 237ms/step - loss: 0.6712 - binary_accuracy: 0.5672 - val_loss: 0.6945 - val_binary_accuracy: 0.4915
# Epoch 4/100
# 26/26 [==============================] - 6s 238ms/step - loss: 0.6624 - binary_accuracy: 0.5770 - val_loss: 0.7097 - val_binary_accuracy: 0.4915
# Epoch 5/100
# 26/26 [==============================] - 6s 236ms/step - loss: 0.6324 - binary_accuracy: 0.6601 - val_loss: 0.7172 - val_binary_accuracy: 0.4915
# Epoch 6/100
# 26/26 [==============================] - 6s 237ms/step - loss: 0.6361 - binary_accuracy: 0.6418 - val_loss: 0.6964 - val_binary_accuracy: 0.4915
# Epoch 7/100
# 26/26 [==============================] - 6s 235ms/step - loss: 0.6472 - binary_accuracy: 0.6169 - val_loss: 0.7261 - val_binary_accuracy: 0.4915
# Epoch 8/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.6440 - binary_accuracy: 0.6322 - val_loss: 0.6943 - val_binary_accuracy: 0.5085
# Epoch 9/100
# 26/26 [==============================] - 6s 237ms/step - loss: 0.6495 - binary_accuracy: 0.6294 - val_loss: 0.6929 - val_binary_accuracy: 0.5000
# Epoch 10/100
# 26/26 [==============================] - 6s 244ms/step - loss: 0.6284 - binary_accuracy: 0.6202 - val_loss: 0.6954 - val_binary_accuracy: 0.4915
# Epoch 11/100
# 26/26 [==============================] - 6s 237ms/step - loss: 0.6548 - binary_accuracy: 0.5821 - val_loss: 0.6940 - val_binary_accuracy: 0.5085
# Epoch 12/100
# 26/26 [==============================] - 6s 240ms/step - loss: 0.6250 - binary_accuracy: 0.6455 - val_loss: 0.7082 - val_binary_accuracy: 0.4915
# Epoch 13/100
# 26/26 [==============================] - 6s 242ms/step - loss: 0.6303 - binary_accuracy: 0.6490 - val_loss: 0.7018 - val_binary_accuracy: 0.5085
# Epoch 14/100
# 26/26 [==============================] - 6s 234ms/step - loss: 0.6345 - binary_accuracy: 0.6418 - val_loss: 0.7000 - val_binary_accuracy: 0.5085
# Epoch 15/100
# 26/26 [==============================] - 6s 241ms/step - loss: 0.6096 - binary_accuracy: 0.6635 - val_loss: 0.6994 - val_binary_accuracy: 0.4915
# Epoch 16/100
# 26/26 [==============================] - 6s 240ms/step - loss: 0.6227 - binary_accuracy: 0.6430 - val_loss: 0.8000 - val_binary_accuracy: 0.5085
# Epoch 17/100
# 26/26 [==============================] - 6s 240ms/step - loss: 0.6362 - binary_accuracy: 0.5945 - val_loss: 0.6930 - val_binary_accuracy: 0.4746
# Epoch 18/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.6212 - binary_accuracy: 0.6466 - val_loss: 1.4729 - val_binary_accuracy: 0.4915
# Epoch 19/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.6192 - binary_accuracy: 0.6748 - val_loss: 0.9747 - val_binary_accuracy: 0.4915
# Epoch 20/100
# 26/26 [==============================] - 6s 242ms/step - loss: 0.6357 - binary_accuracy: 0.6294 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Epoch 21/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.6190 - binary_accuracy: 0.6442 - val_loss: 0.7451 - val_binary_accuracy: 0.5085
# Epoch 22/100
# 26/26 [==============================] - 6s 242ms/step - loss: 0.6181 - binary_accuracy: 0.6601 - val_loss: 0.7203 - val_binary_accuracy: 0.5085
# Epoch 23/100
# 26/26 [==============================] - 6s 249ms/step - loss: 0.5949 - binary_accuracy: 0.6940 - val_loss: 0.6898 - val_binary_accuracy: 0.5085
# Epoch 24/100
# 26/26 [==============================] - 6s 247ms/step - loss: 0.5925 - binary_accuracy: 0.6731 - val_loss: 0.6952 - val_binary_accuracy: 0.4915
# Epoch 25/100
# 26/26 [==============================] - 6s 246ms/step - loss: 0.5987 - binary_accuracy: 0.6773 - val_loss: 0.7131 - val_binary_accuracy: 0.5085
# Epoch 26/100
# 26/26 [==============================] - 6s 247ms/step - loss: 0.5992 - binary_accuracy: 0.6553 - val_loss: 0.6942 - val_binary_accuracy: 0.4915
# Epoch 27/100
# 26/26 [==============================] - 6s 239ms/step - loss: 0.6040 - binary_accuracy: 0.6601 - val_loss: 0.7245 - val_binary_accuracy: 0.5085
# Epoch 28/100
# 26/26 [==============================] - 6s 236ms/step - loss: 0.5950 - binary_accuracy: 0.6675 - val_loss: 0.7010 - val_binary_accuracy: 0.5085
# Epoch 29/100
# 26/26 [==============================] - 6s 241ms/step - loss: 0.6201 - binary_accuracy: 0.6479 - val_loss: 0.8383 - val_binary_accuracy: 0.5085
# Epoch 30/100
# 26/26 [==============================] - 6s 250ms/step - loss: 0.5981 - binary_accuracy: 0.6851 - val_loss: 0.8946 - val_binary_accuracy: 0.5085
# Epoch 31/100
# 26/26 [==============================] - 7s 256ms/step - loss: 0.5842 - binary_accuracy: 0.6699 - val_loss: 0.7337 - val_binary_accuracy: 0.5085
# Epoch 32/100
# 26/26 [==============================] - 6s 241ms/step - loss: 0.6234 - binary_accuracy: 0.6766 - val_loss: 0.6942 - val_binary_accuracy: 0.5085
# Epoch 33/100
# 26/26 [==============================] - 6s 244ms/step - loss: 0.5914 - binary_accuracy: 0.6968 - val_loss: 0.7796 - val_binary_accuracy: 0.4915
# Epoch 34/100
# 26/26 [==============================] - 6s 243ms/step - loss: 0.5966 - binary_accuracy: 0.6846 - val_loss: 0.6961 - val_binary_accuracy: 0.5085
# Epoch 35/100
# 26/26 [==============================] - 6s 244ms/step - loss: 0.5967 - binary_accuracy: 0.6675 - val_loss: 0.7704 - val_binary_accuracy: 0.5085
# Epoch 36/100
# 26/26 [==============================] - 6s 239ms/step - loss: 0.5928 - binary_accuracy: 0.6797 - val_loss: 0.7107 - val_binary_accuracy: 0.5085
# Epoch 37/100
# 26/26 [==============================] - 6s 244ms/step - loss: 0.5905 - binary_accuracy: 0.6993 - val_loss: 0.7023 - val_binary_accuracy: 0.5085
# Epoch 38/100
# 26/26 [==============================] - 6s 246ms/step - loss: 0.6119 - binary_accuracy: 0.6797 - val_loss: 0.7575 - val_binary_accuracy: 0.5085
# Epoch 39/100
# 26/26 [==============================] - 7s 258ms/step - loss: 0.5925 - binary_accuracy: 0.6731 - val_loss: 0.7833 - val_binary_accuracy: 0.5085
# Epoch 40/100
# 26/26 [==============================] - 6s 236ms/step - loss: 0.5884 - binary_accuracy: 0.6741 - val_loss: 0.6961 - val_binary_accuracy: 0.4915
# Epoch 41/100
# 26/26 [==============================] - 6s 242ms/step - loss: 0.6138 - binary_accuracy: 0.6333 - val_loss: 0.6942 - val_binary_accuracy: 0.4915
# Epoch 42/100
# 26/26 [==============================] - 6s 247ms/step - loss: 0.5729 - binary_accuracy: 0.6947 - val_loss: 0.7221 - val_binary_accuracy: 0.4915
# Epoch 43/100
# 26/26 [==============================] - 6s 243ms/step - loss: 0.5516 - binary_accuracy: 0.7213 - val_loss: 0.6930 - val_binary_accuracy: 0.4831
# Epoch 44/100
# 26/26 [==============================] - 6s 241ms/step - loss: 0.5994 - binary_accuracy: 0.7015 - val_loss: 0.7302 - val_binary_accuracy: 0.5085
# Epoch 45/100
# 26/26 [==============================] - 6s 242ms/step - loss: 0.5864 - binary_accuracy: 0.6553 - val_loss: 0.7666 - val_binary_accuracy: 0.5085
# Epoch 46/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.6046 - binary_accuracy: 0.6528 - val_loss: 0.8155 - val_binary_accuracy: 0.5085
# Epoch 47/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.5686 - binary_accuracy: 0.6947 - val_loss: 0.7044 - val_binary_accuracy: 0.5085
# Epoch 48/100
# 26/26 [==============================] - 6s 248ms/step - loss: 0.5961 - binary_accuracy: 0.6724 - val_loss: 0.9592 - val_binary_accuracy: 0.4915
# Epoch 49/100
# 26/26 [==============================] - 6s 236ms/step - loss: 0.5881 - binary_accuracy: 0.7015 - val_loss: 0.9106 - val_binary_accuracy: 0.5085
# Epoch 50/100
# 26/26 [==============================] - 6s 241ms/step - loss: 0.5886 - binary_accuracy: 0.6971 - val_loss: 0.7043 - val_binary_accuracy: 0.5085
# Epoch 51/100
# 26/26 [==============================] - 6s 235ms/step - loss: 0.5902 - binary_accuracy: 0.6617 - val_loss: 0.7585 - val_binary_accuracy: 0.4915
# Epoch 52/100
# 26/26 [==============================] - 6s 249ms/step - loss: 0.5729 - binary_accuracy: 0.6851 - val_loss: 0.7643 - val_binary_accuracy: 0.4915
# Epoch 53/100
# 26/26 [==============================] - 6s 241ms/step - loss: 0.5748 - binary_accuracy: 0.6895 - val_loss: 0.7329 - val_binary_accuracy: 0.4915
# Epoch 54/100
# 26/26 [==============================] - 6s 244ms/step - loss: 0.5826 - binary_accuracy: 0.6895 - val_loss: 0.7462 - val_binary_accuracy: 0.4915
# Epoch 55/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.5721 - binary_accuracy: 0.6968 - val_loss: 0.7419 - val_binary_accuracy: 0.4915
# Epoch 56/100
# 26/26 [==============================] - 6s 246ms/step - loss: 0.5518 - binary_accuracy: 0.6968 - val_loss: 0.8541 - val_binary_accuracy: 0.4915
# Epoch 57/100
# 26/26 [==============================] - 6s 242ms/step - loss: 0.5824 - binary_accuracy: 0.7139 - val_loss: 0.7284 - val_binary_accuracy: 0.4915
# Epoch 58/100
# 26/26 [==============================] - 6s 242ms/step - loss: 0.5663 - binary_accuracy: 0.6919 - val_loss: 0.6947 - val_binary_accuracy: 0.4915
# Epoch 59/100
# 26/26 [==============================] - 6s 246ms/step - loss: 0.5571 - binary_accuracy: 0.7066 - val_loss: 0.7003 - val_binary_accuracy: 0.5085
# Epoch 60/100
# 26/26 [==============================] - 6s 244ms/step - loss: 0.5485 - binary_accuracy: 0.7262 - val_loss: 0.7178 - val_binary_accuracy: 0.5085
# Epoch 61/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.5508 - binary_accuracy: 0.7188 - val_loss: 0.7484 - val_binary_accuracy: 0.5085
# Epoch 62/100
# 26/26 [==============================] - 6s 248ms/step - loss: 0.5426 - binary_accuracy: 0.7359 - val_loss: 0.7317 - val_binary_accuracy: 0.5085
# Epoch 63/100
# 26/26 [==============================] - 6s 243ms/step - loss: 0.5596 - binary_accuracy: 0.7042 - val_loss: 0.7370 - val_binary_accuracy: 0.5085
# Epoch 64/100
# 26/26 [==============================] - 7s 251ms/step - loss: 0.5468 - binary_accuracy: 0.7091 - val_loss: 0.8445 - val_binary_accuracy: 0.5085
# Epoch 65/100
# 26/26 [==============================] - 6s 246ms/step - loss: 0.5726 - binary_accuracy: 0.6866 - val_loss: 0.7279 - val_binary_accuracy: 0.5085
# Epoch 66/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.5393 - binary_accuracy: 0.7213 - val_loss: 0.7237 - val_binary_accuracy: 0.5085
# Epoch 67/100
# 26/26 [==============================] - 7s 259ms/step - loss: 0.5551 - binary_accuracy: 0.7067 - val_loss: 0.7560 - val_binary_accuracy: 0.5085
# Epoch 68/100
# 26/26 [==============================] - 6s 242ms/step - loss: 0.5871 - binary_accuracy: 0.7040 - val_loss: 0.7443 - val_binary_accuracy: 0.4915
# Epoch 69/100
# 26/26 [==============================] - 6s 242ms/step - loss: 0.5380 - binary_accuracy: 0.7286 - val_loss: 0.6953 - val_binary_accuracy: 0.5085
# Epoch 70/100
# 26/26 [==============================] - 7s 250ms/step - loss: 0.5338 - binary_accuracy: 0.7308 - val_loss: 0.7070 - val_binary_accuracy: 0.5085
# Epoch 71/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.6086 - binary_accuracy: 0.6601 - val_loss: 0.6935 - val_binary_accuracy: 0.5085
# Epoch 72/100
# 26/26 [==============================] - 6s 244ms/step - loss: 0.5644 - binary_accuracy: 0.6846 - val_loss: 0.6965 - val_binary_accuracy: 0.4915
# Epoch 73/100
# 26/26 [==============================] - 6s 242ms/step - loss: 0.5429 - binary_accuracy: 0.7408 - val_loss: 0.6986 - val_binary_accuracy: 0.5085
# Epoch 74/100
# 26/26 [==============================] - 6s 238ms/step - loss: 0.5719 - binary_accuracy: 0.6895 - val_loss: 0.8105 - val_binary_accuracy: 0.5085
# Epoch 75/100
# 26/26 [==============================] - 6s 238ms/step - loss: 0.5223 - binary_accuracy: 0.7189 - val_loss: 0.6961 - val_binary_accuracy: 0.4915
# Epoch 76/100
# 26/26 [==============================] - 9s 330ms/step - loss: 0.5947 - binary_accuracy: 0.6779 - val_loss: 0.6964 - val_binary_accuracy: 0.4915
# Epoch 77/100
# 26/26 [==============================] - 7s 250ms/step - loss: 0.5561 - binary_accuracy: 0.7188 - val_loss: 0.7450 - val_binary_accuracy: 0.4915
# Epoch 78/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.5852 - binary_accuracy: 0.6626 - val_loss: 0.7076 - val_binary_accuracy: 0.4915
# Epoch 79/100
# 26/26 [==============================] - 6s 243ms/step - loss: 0.5545 - binary_accuracy: 0.7213 - val_loss: 0.8304 - val_binary_accuracy: 0.4915
# Epoch 80/100
# 26/26 [==============================] - 8s 303ms/step - loss: 0.5474 - binary_accuracy: 0.7164 - val_loss: 0.6910 - val_binary_accuracy: 0.5000
# Epoch 81/100
# 26/26 [==============================] - 6s 244ms/step - loss: 0.5450 - binary_accuracy: 0.7359 - val_loss: 0.7706 - val_binary_accuracy: 0.4915
# Epoch 82/100
# 26/26 [==============================] - 6s 249ms/step - loss: 0.5479 - binary_accuracy: 0.6944 - val_loss: 0.7086 - val_binary_accuracy: 0.5085
# Epoch 83/100
# 26/26 [==============================] - 6s 247ms/step - loss: 0.5735 - binary_accuracy: 0.6846 - val_loss: 0.7176 - val_binary_accuracy: 0.4915
# Epoch 84/100
# 26/26 [==============================] - 6s 248ms/step - loss: 0.5391 - binary_accuracy: 0.7042 - val_loss: 0.7337 - val_binary_accuracy: 0.5085
# Epoch 85/100
# 26/26 [==============================] - 7s 252ms/step - loss: 0.5372 - binary_accuracy: 0.7090 - val_loss: 0.7271 - val_binary_accuracy: 0.4915
# Epoch 86/100
# 26/26 [==============================] - 6s 248ms/step - loss: 0.5363 - binary_accuracy: 0.7237 - val_loss: 0.8368 - val_binary_accuracy: 0.5085
# Epoch 87/100
# 26/26 [==============================] - 7s 252ms/step - loss: 0.5491 - binary_accuracy: 0.7115 - val_loss: 0.9251 - val_binary_accuracy: 0.5085
# Epoch 88/100
# 26/26 [==============================] - 6s 246ms/step - loss: 0.5647 - binary_accuracy: 0.6993 - val_loss: 0.7580 - val_binary_accuracy: 0.5085
# Epoch 89/100
# 26/26 [==============================] - 7s 254ms/step - loss: 0.5156 - binary_accuracy: 0.7404 - val_loss: 0.7276 - val_binary_accuracy: 0.4915
# Epoch 90/100
# 26/26 [==============================] - 6s 247ms/step - loss: 0.5664 - binary_accuracy: 0.7139 - val_loss: 0.8179 - val_binary_accuracy: 0.5085
# Epoch 91/100
# 26/26 [==============================] - 7s 251ms/step - loss: 0.5576 - binary_accuracy: 0.7286 - val_loss: 0.6999 - val_binary_accuracy: 0.5085
# Epoch 92/100
# 26/26 [==============================] - 6s 246ms/step - loss: 0.5071 - binary_accuracy: 0.7628 - val_loss: 0.6953 - val_binary_accuracy: 0.4915
# Epoch 93/100
# 26/26 [==============================] - 7s 252ms/step - loss: 0.4930 - binary_accuracy: 0.7404 - val_loss: 0.6940 - val_binary_accuracy: 0.5085
# Epoch 94/100
# 26/26 [==============================] - 6s 246ms/step - loss: 0.5190 - binary_accuracy: 0.7164 - val_loss: 0.6977 - val_binary_accuracy: 0.4915
# Epoch 95/100
# 26/26 [==============================] - 6s 243ms/step - loss: 0.5273 - binary_accuracy: 0.7506 - val_loss: 0.7269 - val_binary_accuracy: 0.5085
# Epoch 96/100
# 26/26 [==============================] - 6s 240ms/step - loss: 0.5361 - binary_accuracy: 0.7164 - val_loss: 0.7419 - val_binary_accuracy: 0.5085
# Epoch 97/100
# 26/26 [==============================] - 7s 252ms/step - loss: 0.5281 - binary_accuracy: 0.7506 - val_loss: 0.7059 - val_binary_accuracy: 0.5085
# Epoch 98/100
# 26/26 [==============================] - 7s 250ms/step - loss: 0.5456 - binary_accuracy: 0.7139 - val_loss: 0.8052 - val_binary_accuracy: 0.5085
# Epoch 99/100
# 26/26 [==============================] - 8s 300ms/step - loss: 0.5299 - binary_accuracy: 0.7457 - val_loss: 0.7365 - val_binary_accuracy: 0.5085
# Epoch 100/100
# 26/26 [==============================] - 6s 245ms/step - loss: 0.5549 - binary_accuracy: 0.7188 - val_loss: 0.7059 - val_binary_accuracy: 0.5085

# %%
loss_curves_plot(model_hist)

# %%
accuracy_curves_plot(model_hist,'binary_accuracy')
