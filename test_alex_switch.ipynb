# %%
from Functions import*

# %%
from statistics import *

# %%
test_list_covid, train_list_covid,val_list_covid=create_list_to_load(covid=True)

test_list_Noncovid, train_list_Noncovid,val_list_Noncovid=create_list_to_load(covid=False)

# %%
test_covid_labels=create_list_labels(test_list_covid,covid=True)
train_covid_labels=create_list_labels(train_list_covid,covid=True)
val_covid_labels=create_list_labels(val_list_covid,covid=True)

test_Noncovid_labels=create_list_labels(test_list_Noncovid,covid=False)
train_Noncovid_labels=create_list_labels(train_list_Noncovid,covid=False)
val_Noncovid_labels=create_list_labels(val_list_Noncovid,covid=False)

# %%
test_list,test_labels=concatenate_lists_and_labels(test_list_covid,test_covid_labels,test_list_Noncovid,test_Noncovid_labels)
train_list,train_labels=concatenate_lists_and_labels(train_list_covid,train_covid_labels,train_list_Noncovid,train_Noncovid_labels)
val_list,val_labels=concatenate_lists_and_labels(val_list_covid,val_covid_labels,val_list_Noncovid,val_Noncovid_labels)

# %%
test_list,test_labels=shuffle_lists(test_list, test_labels)
train_list,train_labels=shuffle_lists(train_list, train_labels)
val_list,val_labels=shuffle_lists(val_list, val_labels)

# %%
total_list=test_list+train_list+val_list
total_labels=test_labels+train_labels+val_labels

# %%
total_list,total_labels=shuffle_lists(total_list, total_labels)

train_percent=0.8
length = len(total_list)
train_length = int(length*train_percent)

train_set=total_list[0:train_length]
train_labels=total_labels[0:train_length]
val_set=total_list[:train_length]
val_labels=total_labels[:train_length]

# %%
#the article precises the size of the images as (480,480)

img_w,img_h,img_ch=480,480,1


train_set=load_data(train_set,img_w,img_h,img_ch)
val_set=load_data(val_set,img_w,img_h,img_ch)


train_labels=np.array(train_labels)
val_labels=np.array(val_labels)

# %%
from skimage.io import imshow

# %%
imshow(np.squeeze(train_set[0]),cmap='gray')

# %%
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %%
INPUT_SHAPE=480,480,1
N_CLASSES=1

K.clear_session()
my_model=Alex_model(1,480,480)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 480, 480, 8)       80
# _________________________________________________________________
# activation (Activation)      (None, 480, 480, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 240, 240, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 240, 240, 16)      1168
# _________________________________________________________________
# activation_1 (Activation)    (None, 240, 240, 16)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 120, 120, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 120, 120, 32)      4640
# _________________________________________________________________
# activation_2 (Activation)    (None, 120, 120, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 120, 120, 32)      9248
# _________________________________________________________________
# activation_3 (Activation)    (None, 120, 120, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 120, 120, 16)      4624
# _________________________________________________________________
# activation_4 (Activation)    (None, 120, 120, 16)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 60, 60, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 57600)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               7372928
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# activation_5 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# activation_6 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1)                 0
# _________________________________________________________________
# activation_7 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 7,401,009
# Trainable params: 7,401,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
learning_rate=0.0001
optimizer=Adam(learning_rate)
batch_size=16
loss_function = 'binary_crossentropy'
metrics=['binary_accuracy',precision,recall]
n_epochs=100

# %%
my_model.compile(loss=loss_function,optimizer = optimizer,metrics=['binary_accuracy'])

# %%
model_hist=my_model.fit(train_set,train_labels,batch_size,n_epochs,validation_data=(val_set, val_labels))
# Out:
# Train on 596 samples, validate on 596 samples
# Epoch 1/100
# 596/596 [==============================] - 4s 7ms/sample - loss: 0.6887 - binary_accuracy: 0.5587 - val_loss: 0.6685 - val_binary_accuracy: 0.6326
# Epoch 2/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.6592 - binary_accuracy: 0.6544 - val_loss: 0.6139 - val_binary_accuracy: 0.6946
# Epoch 3/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.6358 - binary_accuracy: 0.6460 - val_loss: 0.5767 - val_binary_accuracy: 0.7047
# Epoch 4/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.5869 - binary_accuracy: 0.6628 - val_loss: 0.5389 - val_binary_accuracy: 0.7332
# Epoch 5/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.5616 - binary_accuracy: 0.7265 - val_loss: 0.4625 - val_binary_accuracy: 0.8272
# Epoch 6/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.5122 - binary_accuracy: 0.7567 - val_loss: 0.4230 - val_binary_accuracy: 0.8591
# Epoch 7/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.4437 - binary_accuracy: 0.7785 - val_loss: 0.3293 - val_binary_accuracy: 0.8926
# Epoch 8/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.4030 - binary_accuracy: 0.8020 - val_loss: 0.2742 - val_binary_accuracy: 0.9144
# Epoch 9/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.3630 - binary_accuracy: 0.7919 - val_loss: 0.2380 - val_binary_accuracy: 0.9195
# Epoch 10/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.3372 - binary_accuracy: 0.8255 - val_loss: 0.2073 - val_binary_accuracy: 0.9614
# Epoch 11/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.2915 - binary_accuracy: 0.8658 - val_loss: 0.1506 - val_binary_accuracy: 0.9581
# Epoch 12/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.2516 - binary_accuracy: 0.8624 - val_loss: 0.0850 - val_binary_accuracy: 0.9849
# Epoch 13/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.2180 - binary_accuracy: 0.8725 - val_loss: 0.0677 - val_binary_accuracy: 0.9916
# Epoch 14/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.2162 - binary_accuracy: 0.8792 - val_loss: 0.0417 - val_binary_accuracy: 0.9950
# Epoch 15/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1964 - binary_accuracy: 0.8876 - val_loss: 0.0628 - val_binary_accuracy: 0.9899
# Epoch 16/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.2116 - binary_accuracy: 0.8826 - val_loss: 0.0415 - val_binary_accuracy: 0.9950
# Epoch 17/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1868 - binary_accuracy: 0.8909 - val_loss: 0.0279 - val_binary_accuracy: 0.9966
# Epoch 18/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1746 - binary_accuracy: 0.8993 - val_loss: 0.0258 - val_binary_accuracy: 0.9983
# Epoch 19/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1808 - binary_accuracy: 0.9010 - val_loss: 0.0176 - val_binary_accuracy: 0.9966
# Epoch 20/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1586 - binary_accuracy: 0.9077 - val_loss: 0.0123 - val_binary_accuracy: 0.9983
# Epoch 21/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1638 - binary_accuracy: 0.9060 - val_loss: 0.0151 - val_binary_accuracy: 0.9983
# Epoch 22/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1649 - binary_accuracy: 0.9060 - val_loss: 0.0114 - val_binary_accuracy: 0.9983
# Epoch 23/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1492 - binary_accuracy: 0.9161 - val_loss: 0.0088 - val_binary_accuracy: 0.9983
# Epoch 24/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1343 - binary_accuracy: 0.9111 - val_loss: 0.0053 - val_binary_accuracy: 0.9983
# Epoch 25/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1526 - binary_accuracy: 0.9027 - val_loss: 0.0075 - val_binary_accuracy: 1.0000
# Epoch 26/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1296 - binary_accuracy: 0.9245 - val_loss: 0.0045 - val_binary_accuracy: 1.0000
# Epoch 27/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1459 - binary_accuracy: 0.9077 - val_loss: 0.0050 - val_binary_accuracy: 0.9983
# Epoch 28/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1279 - binary_accuracy: 0.9161 - val_loss: 0.0049 - val_binary_accuracy: 1.0000
# Epoch 29/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1446 - binary_accuracy: 0.9111 - val_loss: 0.0073 - val_binary_accuracy: 1.0000
# Epoch 30/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1484 - binary_accuracy: 0.9077 - val_loss: 0.0061 - val_binary_accuracy: 0.9983
# Epoch 31/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1594 - binary_accuracy: 0.8977 - val_loss: 0.0022 - val_binary_accuracy: 1.0000
# Epoch 32/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1171 - binary_accuracy: 0.9329 - val_loss: 0.0018 - val_binary_accuracy: 1.0000
# Epoch 33/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1417 - binary_accuracy: 0.8909 - val_loss: 0.0015 - val_binary_accuracy: 1.0000
# Epoch 34/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1469 - binary_accuracy: 0.8943 - val_loss: 0.0016 - val_binary_accuracy: 1.0000
# Epoch 35/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1191 - binary_accuracy: 0.9195 - val_loss: 0.0015 - val_binary_accuracy: 1.0000
# Epoch 36/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1330 - binary_accuracy: 0.9044 - val_loss: 0.0016 - val_binary_accuracy: 1.0000
# Epoch 37/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1450 - binary_accuracy: 0.9060 - val_loss: 0.0011 - val_binary_accuracy: 1.0000
# Epoch 38/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1449 - binary_accuracy: 0.9010 - val_loss: 9.6459e-04 - val_binary_accuracy: 1.0000
# Epoch 39/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1384 - binary_accuracy: 0.9077 - val_loss: 0.0012 - val_binary_accuracy: 1.0000
# Epoch 40/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1564 - binary_accuracy: 0.9027 - val_loss: 0.0049 - val_binary_accuracy: 1.0000
# Epoch 41/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1323 - binary_accuracy: 0.9111 - val_loss: 0.0027 - val_binary_accuracy: 1.0000
# Epoch 42/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1373 - binary_accuracy: 0.9128 - val_loss: 0.0019 - val_binary_accuracy: 1.0000
# Epoch 43/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1508 - binary_accuracy: 0.9195 - val_loss: 0.0020 - val_binary_accuracy: 0.9983
# Epoch 44/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1308 - binary_accuracy: 0.9211 - val_loss: 0.0021 - val_binary_accuracy: 0.9983
# Epoch 45/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1512 - binary_accuracy: 0.8993 - val_loss: 5.1444e-04 - val_binary_accuracy: 1.0000
# Epoch 46/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1613 - binary_accuracy: 0.9044 - val_loss: 0.0070 - val_binary_accuracy: 0.9983
# Epoch 47/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1914 - binary_accuracy: 0.8909 - val_loss: 0.0343 - val_binary_accuracy: 0.9933
# Epoch 48/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1939 - binary_accuracy: 0.8926 - val_loss: 0.0122 - val_binary_accuracy: 0.9983
# Epoch 49/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1516 - binary_accuracy: 0.9262 - val_loss: 0.0067 - val_binary_accuracy: 1.0000
# Epoch 50/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1523 - binary_accuracy: 0.8960 - val_loss: 0.0029 - val_binary_accuracy: 1.0000
# Epoch 51/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1432 - binary_accuracy: 0.9144 - val_loss: 0.0024 - val_binary_accuracy: 1.0000
# Epoch 52/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1376 - binary_accuracy: 0.9228 - val_loss: 0.0018 - val_binary_accuracy: 1.0000
# Epoch 53/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1229 - binary_accuracy: 0.9211 - val_loss: 0.0023 - val_binary_accuracy: 1.0000
# Epoch 54/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1549 - binary_accuracy: 0.9144 - val_loss: 0.0033 - val_binary_accuracy: 0.9983
# Epoch 55/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1370 - binary_accuracy: 0.9094 - val_loss: 0.0012 - val_binary_accuracy: 1.0000
# Epoch 56/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1373 - binary_accuracy: 0.9111 - val_loss: 7.9415e-04 - val_binary_accuracy: 1.0000
# Epoch 57/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1503 - binary_accuracy: 0.8926 - val_loss: 9.8309e-04 - val_binary_accuracy: 1.0000
# Epoch 58/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1335 - binary_accuracy: 0.9228 - val_loss: 0.0012 - val_binary_accuracy: 1.0000
# Epoch 59/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1418 - binary_accuracy: 0.8977 - val_loss: 6.7893e-04 - val_binary_accuracy: 1.0000
# Epoch 60/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1471 - binary_accuracy: 0.9027 - val_loss: 5.2154e-04 - val_binary_accuracy: 1.0000
# Epoch 61/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1401 - binary_accuracy: 0.8926 - val_loss: 0.0035 - val_binary_accuracy: 0.9983
# Epoch 62/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1471 - binary_accuracy: 0.9144 - val_loss: 0.0012 - val_binary_accuracy: 1.0000
# Epoch 63/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1454 - binary_accuracy: 0.9094 - val_loss: 0.0022 - val_binary_accuracy: 1.0000
# Epoch 64/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1361 - binary_accuracy: 0.9262 - val_loss: 8.6692e-04 - val_binary_accuracy: 1.0000
# Epoch 65/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1433 - binary_accuracy: 0.9094 - val_loss: 0.0014 - val_binary_accuracy: 1.0000
# Epoch 66/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1734 - binary_accuracy: 0.8842 - val_loss: 8.0158e-04 - val_binary_accuracy: 1.0000
# Epoch 67/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1356 - binary_accuracy: 0.9094 - val_loss: 0.0030 - val_binary_accuracy: 1.0000
# Epoch 68/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1385 - binary_accuracy: 0.9178 - val_loss: 0.0011 - val_binary_accuracy: 1.0000
# Epoch 69/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1466 - binary_accuracy: 0.8993 - val_loss: 3.2347e-04 - val_binary_accuracy: 1.0000
# Epoch 70/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1421 - binary_accuracy: 0.9128 - val_loss: 2.7836e-04 - val_binary_accuracy: 1.0000
# Epoch 71/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1229 - binary_accuracy: 0.9211 - val_loss: 3.2375e-04 - val_binary_accuracy: 1.0000
# Epoch 72/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1543 - binary_accuracy: 0.9010 - val_loss: 2.3170e-04 - val_binary_accuracy: 1.0000
# Epoch 73/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1520 - binary_accuracy: 0.8943 - val_loss: 3.2099e-04 - val_binary_accuracy: 1.0000
# Epoch 74/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1692 - binary_accuracy: 0.8842 - val_loss: 2.1298e-04 - val_binary_accuracy: 1.0000
# Epoch 75/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1328 - binary_accuracy: 0.9228 - val_loss: 2.0134e-04 - val_binary_accuracy: 1.0000
# Epoch 76/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1423 - binary_accuracy: 0.8960 - val_loss: 2.5925e-04 - val_binary_accuracy: 1.0000
# Epoch 77/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1475 - binary_accuracy: 0.9044 - val_loss: 2.5784e-04 - val_binary_accuracy: 1.0000
# Epoch 78/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1329 - binary_accuracy: 0.9144 - val_loss: 1.4184e-04 - val_binary_accuracy: 1.0000
# Epoch 79/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1365 - binary_accuracy: 0.9044 - val_loss: 2.2290e-04 - val_binary_accuracy: 1.0000
# Epoch 80/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1328 - binary_accuracy: 0.9094 - val_loss: 1.6301e-04 - val_binary_accuracy: 1.0000
# Epoch 81/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1455 - binary_accuracy: 0.8926 - val_loss: 1.5001e-04 - val_binary_accuracy: 1.0000
# Epoch 82/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1537 - binary_accuracy: 0.8943 - val_loss: 1.1379e-04 - val_binary_accuracy: 1.0000
# Epoch 83/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1478 - binary_accuracy: 0.9077 - val_loss: 9.8508e-05 - val_binary_accuracy: 1.0000
# Epoch 84/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1368 - binary_accuracy: 0.9144 - val_loss: 1.0742e-04 - val_binary_accuracy: 1.0000
# Epoch 85/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1239 - binary_accuracy: 0.9195 - val_loss: 1.4031e-04 - val_binary_accuracy: 1.0000
# Epoch 86/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1380 - binary_accuracy: 0.9027 - val_loss: 1.5714e-04 - val_binary_accuracy: 1.0000
# Epoch 87/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1327 - binary_accuracy: 0.9161 - val_loss: 0.0019 - val_binary_accuracy: 1.0000
# Epoch 88/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1242 - binary_accuracy: 0.9144 - val_loss: 0.0011 - val_binary_accuracy: 1.0000
# Epoch 89/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1448 - binary_accuracy: 0.9111 - val_loss: 0.0012 - val_binary_accuracy: 1.0000
# Epoch 90/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1497 - binary_accuracy: 0.8926 - val_loss: 4.0064e-04 - val_binary_accuracy: 1.0000
# Epoch 91/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1462 - binary_accuracy: 0.8977 - val_loss: 1.9041e-04 - val_binary_accuracy: 1.0000
# Epoch 92/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1439 - binary_accuracy: 0.9144 - val_loss: 0.0019 - val_binary_accuracy: 0.9983
# Epoch 93/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1521 - binary_accuracy: 0.9077 - val_loss: 6.9149e-04 - val_binary_accuracy: 1.0000
# Epoch 94/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1449 - binary_accuracy: 0.9094 - val_loss: 0.0106 - val_binary_accuracy: 0.9983
# Epoch 95/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1509 - binary_accuracy: 0.8977 - val_loss: 0.0041 - val_binary_accuracy: 0.9983
# Epoch 96/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1570 - binary_accuracy: 0.8909 - val_loss: 7.1340e-04 - val_binary_accuracy: 1.0000
# Epoch 97/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1498 - binary_accuracy: 0.8977 - val_loss: 4.1386e-04 - val_binary_accuracy: 1.0000
# Epoch 98/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1377 - binary_accuracy: 0.8977 - val_loss: 2.9108e-04 - val_binary_accuracy: 1.0000
# Epoch 99/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1427 - binary_accuracy: 0.9111 - val_loss: 2.4143e-04 - val_binary_accuracy: 1.0000
# Epoch 100/100
# 596/596 [==============================] - 2s 3ms/sample - loss: 0.1237 - binary_accuracy: 0.9195 - val_loss: 1.1194e-04 - val_binary_accuracy: 1.0000

# %%
loss_curves_plot(model_hist)

# %%
accuracy_curves_plot(model_hist,'binary_accuracy')

# %%
Sample = train_list[9]
Img = imread(Sample)
Img = Img[:,:,0]
Img = Img/255
Img = resize(Img, (img_h, img_w), anti_aliasing = True).astype('float32')
Img = np.expand_dims(Img, axis = 2)
Img = np.expand_dims(Img, axis = 0)
preds = my_model.predict(Img)
class_idx = np.argmax(preds[0])
print(class_idx)
class_output = my_model.output[:, class_idx]
last_conv_layer = my_model.get_layer("conv2d_4")
grads = K.gradients(class_output, last_conv_layer.output)[0]
pooled_grads = K.mean(grads, axis=(0, 1, 2))
iterate = K.function([my_model.input], [pooled_grads, last_conv_layer.output[0]])
pooled_grads_value, conv_layer_output_value = iterate([Img])
for i in range(16):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
heatmap = np.mean(conv_layer_output_value, axis=-1)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)
img = cv2.imread(Sample)
img = cv2.resize(img, (480, 480), interpolation = cv2.INTER_AREA)
#img = img/255
heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)
plt.figure()
plt.imshow(img)
plt.figure()
plt.imshow(superimposed_img)
# Out:
# 0
